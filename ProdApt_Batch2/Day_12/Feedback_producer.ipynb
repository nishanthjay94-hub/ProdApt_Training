# %%
from kafka import KafkaProducer
import pandas as pd
import json
import time

producer = KafkaProducer(
    bootstrap_servers='localhost:9092',
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

df = pd.read_csv("feedback_status.csv")

while True:
    for _, row in df.iterrows():

        data = {
            "user": row['user'],
            "restaurant": row['restaurant'],
            "rating": int(row['rating']),
            "comment": row['comment']
        }

        producer.send('feedback_topic', value=data)

        print("Feedback Sent:", data)

        time.sleep(4)
# Out:
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
# Feedback Sent: {'user': 'Rohan', 'restaurant': 'KFC', 'rating': 4, 'comment': 'Tasty Burger'}
# Feedback Sent: {'user': 'Sneha', 'restaurant': 'McDonalds', 'rating': 3, 'comment': 'Okay'}
# Feedback Sent: {'user': 'Karan', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast Delivery'}
# Feedback Sent: {'user': 'John', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Excellent'}
# Feedback Sent: {'user': 'Ravi', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Good Pizza'}
# Feedback Sent: {'user': 'Asha', 'restaurant': 'Subway', 'rating': 3, 'comment': 'Average'}
# Feedback Sent: {'user': 'Meena', 'restaurant': 'KFC', 'rating': 5, 'comment': 'Awesome'}
# Feedback Sent: {'user': 'David', 'restaurant': 'McDonalds', 'rating': 2, 'comment': 'Cold Fries'}
# Feedback Sent: {'user': 'Arun', 'restaurant': 'Dominos', 'rating': 4, 'comment': 'Nice Pasta'}
# Feedback Sent: {'user': 'Priya', 'restaurant': 'Subway', 'rating': 5, 'comment': 'Fresh Wrap'}
